# %% [markdown]
# # Recommender system week 2

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("HW1-data.csv")

# %%
data
# Out:
#     User  Gender (1 =F, 0=M)  260: Star Wars: Episode IV - A New Hope (1977)  \
# 0    755                   0                                             1.0
# 1   5277                   0                                             5.0
# 2   1577                   1                                             NaN
# 3   4388                   0                                             NaN
# 4   1202                   1                                             4.0
# 5   3823                   1                                             2.0
# 6   5448                   0                                             NaN
# 7   5347                   0                                             4.0
# 8   4117                   1                                             5.0
# 9   2765                   0                                             4.0
# 10  5450                   1                                             2.0
# ...

# %% [markdown]
# # ((((( Mean )))))

# %% [markdown]
# Mean Rating: Calculate the mean rating for each movie, order with the highest rating listed first, and submit the top three (along with the mean scores for the top two).

# %%
 mean = data.agg(['mean'])

# %%
mean[:]
# Out:
#         User  Gender (1 =F, 0=M)  \
# mean  3658.1                0.45
#
#       260: Star Wars: Episode IV - A New Hope (1977)  \
# mean                                        3.266667
#
#       1210: Star Wars: Episode VI - Return of the Jedi (1983)  \
# mean                                                3.0
#
#       356: Forrest Gump (1994)  318: Shawshank Redemption, The (1994)  \
# mean                       2.7                                    3.6
#
#       593: Silence of the Lambs, The (1991)  3578: Gladiator (2000)  \
# mean                                 3.0625                2.916667
#
#       1: Toy Story (1995)  2028: Saving Private Ryan (1998)  ...  \
# mean             2.823529                               3.0  ...
#
#       2396: Shakespeare in Love (1998)  2916: Total Recall (1990)  \
# mean                          2.909091                   1.916667
#
#       780: Independence Day (ID4) (1996)  541: Blade Runner (1982)  \
# ...

# %%
mean.drop(['Gender (1 =F, 0=M)','User'],axis = 1 , inplace = True)

# %%
mean
# Out:
#       260: Star Wars: Episode IV - A New Hope (1977)  \
# mean                                        3.266667
#
#       1210: Star Wars: Episode VI - Return of the Jedi (1983)  \
# mean                                                3.0
#
#       356: Forrest Gump (1994)  318: Shawshank Redemption, The (1994)  \
# mean                       2.7                                    3.6
#
#       593: Silence of the Lambs, The (1991)  3578: Gladiator (2000)  \
# mean                                 3.0625                2.916667
#
#       1: Toy Story (1995)  2028: Saving Private Ryan (1998)  \
# mean             2.823529                               3.0
#
#       296: Pulp Fiction (1994)  1259: Stand by Me (1986)  \
# mean                       3.0                  2.636364
#
#       2396: Shakespeare in Love (1998)  2916: Total Recall (1990)  \
# mean                          2.909091                   1.916667
#
# ...

# %%
mean.sort_values(by = 'mean', axis=1, ascending=False, inplace=False, kind='quicksort', na_position='last')
# Out:
#       318: Shawshank Redemption, The (1994)  \
# mean                                    3.6
#
#       260: Star Wars: Episode IV - A New Hope (1977)  \
# mean                                        3.266667
#
#       541: Blade Runner (1982)  1265: Groundhog Day (1993)  \
# mean                  3.222222                    3.166667
#
#       593: Silence of the Lambs, The (1991)  296: Pulp Fiction (1994)  \
# mean                                 3.0625                       3.0
#
#       527: Schindler's List (1993)  \
# mean                           3.0
#
#       1210: Star Wars: Episode VI - Return of the Jedi (1983)  \
# mean                                                3.0
#
#       34: Babe (1995)  2028: Saving Private Ryan (1998)  \
# mean              3.0                               3.0
#
#       3578: Gladiator (2000)  1198: Raiders of the Lost Ark (1981)  \
# mean                2.916667                              2.909091
#
# ...

# %% [markdown]
# # check 1

# %%
mean['356: Forrest Gump (1994)']
# Out:
# mean    2.7
# Name: 356: Forrest Gump (1994), dtype: float64

# %% [markdown]
# # 2 -(((((( Count )))))))

# %% [markdown]
# Rating Count (popularity): Count the number of ratings for each movie, order with the most number of ratings first, and submit the top three (along with the counts for the top two).

# %%
 count = data.agg(['count'])

# %%
count
# Out:
#        User  Gender (1 =F, 0=M)  \
# count    20                  20
#
#        260: Star Wars: Episode IV - A New Hope (1977)  \
# count                                              15
#
#        1210: Star Wars: Episode VI - Return of the Jedi (1983)  \
# count                                                 14
#
#        356: Forrest Gump (1994)  318: Shawshank Redemption, The (1994)  \
# count                        10                                     10
#
#        593: Silence of the Lambs, The (1991)  3578: Gladiator (2000)  \
# count                                     16                      12
#
#        1: Toy Story (1995)  2028: Saving Private Ryan (1998)  ...  \
# count                   17                                11  ...
#
#        2396: Shakespeare in Love (1998)  2916: Total Recall (1990)  \
# count                                11                         12
#
#        780: Independence Day (ID4) (1996)  541: Blade Runner (1982)  \
# ...

# %%
count.sort_values(by = 'count', axis=1, ascending=False, inplace=False, kind='quicksort', na_position='last')
# Out:
#        User  Gender (1 =F, 0=M)  1: Toy Story (1995)  \
# count    20                  20                   17
#
#        593: Silence of the Lambs, The (1991)  \
# count                                     16
#
#        260: Star Wars: Episode IV - A New Hope (1977)  \
# count                                              15
#
#        1210: Star Wars: Episode VI - Return of the Jedi (1983)  \
# count                                                 14
#
#        780: Independence Day (ID4) (1996)  2762: Sixth Sense, The (1999)  \
# count                                  13                             12
#
#        3578: Gladiator (2000)  527: Schindler's List (1993)  ...  \
# count                      12                            12  ...
#
#        2916: Total Recall (1990)  1198: Raiders of the Lost Ark (1981)  \
# count                         12                                    11
#
#        1259: Stand by Me (1986)  2396: Shakespeare in Love (1998)  \
# ...

# %% [markdown]
# # check 2

# %%
count['356: Forrest Gump (1994)']
# Out:
# count    10
# Name: 356: Forrest Gump (1994), dtype: int64

# %% [markdown]
# # 3 - (((((( > 4))))))

# %% [markdown]
# % of ratings 4+ (liking): Calculate the percentage of ratings for each movie that are 4 or higher. Order with the highest percentage first, and submit the to
# p three (along with the percentage for the top two). Notice that the three different measures of "best" reflect different priorities and give different results; this should help you see why you need to be thoughtful about what metrics you use.

# %%
data_3 = data.drop(['User','Gender (1 =F, 0=M)'],axis = 1 )

# %%
data_3
# Out:
#     260: Star Wars: Episode IV - A New Hope (1977)  \
# 0                                              1.0
# 1                                              5.0
# 2                                              NaN
# 3                                              NaN
# 4                                              4.0
# 5                                              2.0
# 6                                              NaN
# 7                                              4.0
# 8                                              5.0
# 9                                              4.0
# 10                                             2.0
# 11                                             3.0
# 12                                             2.0
# 13                                             3.0
# 14                                             4.0
# 15                                             NaN
# 16                                             NaN
# ...

# %%
def ofgreaterthan4(x):
    if (x >= 4):
        return 1
    else :
        return 0 
    
cols = data_3.columns

# %%
data1 = data_3.copy()

# %%
for col in cols :
    data1[col] = data1[col].apply(lambda x: ofgreaterthan4(x))

# %%
data1
# Out:
#     260: Star Wars: Episode IV - A New Hope (1977)  \
# 0                                                0
# 1                                                1
# 2                                                0
# 3                                                0
# 4                                                1
# 5                                                0
# 6                                                0
# 7                                                1
# 8                                                1
# 9                                                1
# 10                                               0
# 11                                               0
# 12                                               0
# 13                                               0
# 14                                               1
# 15                                               0
# 16                                               0
# ...

# %%
Sum = data1.sum()
Count = data_3.count()
Liking = Sum/Count

# %%
Liking.sort_values(ascending=False, inplace=False, kind='quicksort', na_position='last')
# Out:
# 318: Shawshank Redemption, The (1994)                      0.700000
# 260: Star Wars: Episode IV - A New Hope (1977)             0.533333
# 3578: Gladiator (2000)                                     0.500000
# 541: Blade Runner (1982)                                   0.444444
# 593: Silence of the Lambs, The (1991)                      0.437500
# 2571: Matrix, The (1999)                                   0.416667
# 1265: Groundhog Day (1993)                                 0.416667
# 34: Babe (1995)                                            0.400000
# 296: Pulp Fiction (1994)                                   0.363636
# 2028: Saving Private Ryan (1998)                           0.363636
# 1259: Stand by Me (1986)                                   0.363636
# 1210: Star Wars: Episode VI - Return of the Jedi (1983)    0.357143
# 1: Toy Story (1995)                                        0.352941
# 527: Schindler's List (1993)                               0.333333
# ...

# %% [markdown]
# # check 3

# %%
Liking['356: Forrest Gump (1994)']
# Out:
# 0.3

# %% [markdown]
# # 4 -  (((((((( Toy story ))))))))

# %% [markdown]
# Top movies for someone who has seen Toy Story: Calculate movies that most often occur with Movie #1: Toy Story, using the (x+y)/x method described in class. In other words, for each movie, calculate the percentage of Toy Story raters who also rated that movie. Order with the highest percentage first, and submit the top 3 (along with the correlations for the top two). Note, you will have ties -- to break the ties, use the lowest-numbered movie as the higher-ranked one. In other words, if Movies 541 and 318 are tied, then 318 gets the higher rank.

# %%
data_4 = data[data['1: Toy Story (1995)'].notna()]

# %%
data_4
# Out:
#     User  Gender (1 =F, 0=M)  260: Star Wars: Episode IV - A New Hope (1977)  \
# 0    755                   0                                             1.0
# 1   5277                   0                                             5.0
# 2   1577                   1                                             NaN
# 3   4388                   0                                             NaN
# 5   3823                   1                                             2.0
# 7   5347                   0                                             4.0
# 8   4117                   1                                             5.0
# 9   2765                   0                                             4.0
# 10  5450                   1                                             2.0
# 11   139                   0                                             3.0
# 12  1940                   0                                             2.0
# ...

# %%
cols = data_4.columns 
ls =[]
for col in cols :
    perc = data_4[col].count() /  data_4['1: Toy Story (1995)'].count()
    print("Perc of ",col, "is", perc)
    ls.append(perc)
    

    
ls.sort(reverse=True)
print("---------------------")
print("List is ")
print(ls)
# Out:
# Perc of  User is 1.0
# Perc of  Gender (1 =F, 0=M) is 1.0
# Perc of  260: Star Wars: Episode IV - A New Hope (1977) is 0.8235294117647058
# Perc of  1210: Star Wars: Episode VI - Return of the Jedi (1983) is 0.7647058823529411
# Perc of  356: Forrest Gump (1994) is 0.4117647058823529
# Perc of  318: Shawshank Redemption, The (1994) is 0.47058823529411764
# Perc of  593: Silence of the Lambs, The (1991) is 0.7647058823529411
# Perc of  3578: Gladiator (2000) is 0.5294117647058824
# Perc of  1: Toy Story (1995) is 1.0
# Perc of  2028: Saving Private Ryan (1998) is 0.47058823529411764
# Perc of  296: Pulp Fiction (1994) is 0.5882352941176471
# Perc of  1259: Stand by Me (1986) is 0.5294117647058824
# Perc of  2396: Shakespeare in Love (1998) is 0.47058823529411764
# Perc of  2916: Total Recall (1990) is 0.6470588235294118
# Perc of  780: Independence Day (ID4) (1996) is 0.7647058823529411
# Perc of  541: Blade Runner (1982) is 0.4117647058823529
# ...

# %% [markdown]
# # check 4

# %% [markdown]
# Perc of  356: Forrest Gump (1994) is
#
#
# 0.4117647058823529

# %% [markdown]
# # 5 - ((((((corr))))))

# %%
print(data_4.corr()[u'1: Toy Story (1995)'].sort_values(ascending=False).head(6))
# Out:
# 1: Toy Story (1995)                      1.000000
# 318: Shawshank Redemption, The (1994)    0.888523
# 34: Babe (1995)                          0.811107
# 296: Pulp Fiction (1994)                 0.709842
# 2028: Saving Private Ryan (1998)         0.596849
# Gender (1 =F, 0=M)                       0.570232
# Name: 1: Toy Story (1995), dtype: float64

# %% [markdown]
# # check 5

# %% [markdown]
# 356: Forrest Gump (1994)
#
# 0.522913

# %% [markdown]
# # 6 - ((((((()))))))

# %% [markdown]
# Mean rating difference by gender: First, recompute the mean rating for each movie separately for males and for females. And calculate the overall mean rating (across all ratings) for males and females. Submit the two movies that have the greatest differences (one where men are most above women, and one where women are most above men) along with the differences in average. Also submit the difference in overall rating averages (female average - male average).

# %%
#check the data

#data

# %%
# mean all 

data_mean = data.agg(['mean']).drop(['User','Gender (1 =F, 0=M)'],axis = 1)
data_mean
# Out:
#       260: Star Wars: Episode IV - A New Hope (1977)  \
# mean                                        3.266667
#
#       1210: Star Wars: Episode VI - Return of the Jedi (1983)  \
# mean                                                3.0
#
#       356: Forrest Gump (1994)  318: Shawshank Redemption, The (1994)  \
# mean                       2.7                                    3.6
#
#       593: Silence of the Lambs, The (1991)  3578: Gladiator (2000)  \
# mean                                 3.0625                2.916667
#
#       1: Toy Story (1995)  2028: Saving Private Ryan (1998)  \
# mean             2.823529                               3.0
#
#       296: Pulp Fiction (1994)  1259: Stand by Me (1986)  \
# mean                       3.0                  2.636364
#
#       2396: Shakespeare in Love (1998)  2916: Total Recall (1990)  \
# mean                          2.909091                   1.916667
#
# ...

# %%
data_males = data[data['Gender (1 =F, 0=M)']== 0]
data_females = data[data['Gender (1 =F, 0=M)']== 1]

# %%
data_females
# Out:
#     User  Gender (1 =F, 0=M)  260: Star Wars: Episode IV - A New Hope (1977)  \
# 2   1577                   1                                             NaN
# 4   1202                   1                                             4.0
# 5   3823                   1                                             2.0
# 8   4117                   1                                             5.0
# 10  5450                   1                                             2.0
# 13  3118                   1                                             3.0
# 14  4656                   1                                             4.0
# 15  4796                   1                                             NaN
# 17  3048                   1                                             4.0
#
#     1210: Star Wars: Episode VI - Return of the Jedi (1983)  \
# 2                                                 NaN
# 4                                                 3.0
# ...

# %%
# diff_= []
# for col in cols:
#     diff = data_f[col].item() - data_m[col].item()
#     print("diff for ",col,"is : ", diff)
#     diff_.append(diff)
# diff_.sort()
# print(diff_)

# %% [markdown]
# where males are the most : diff for  1198: Raiders of the Lost Ark (1981) is :  -1.6666666666666665
#
#
#
# where females are the most :  diff for  2396: Shakespeare in Love (1998) is :  2.107142857142857

# %%
2.107142857142857 - 1.6666666666666665
# Out:
# 0.4404761904761907

# %% [markdown]
# # Check 6

# %%
data_f = data_females.agg(['mean'])
data_f['356: Forrest Gump (1994)']
# Out:
# mean    3.0
# Name: 356: Forrest Gump (1994), dtype: float64

# %%
data_m = data_males.agg(['mean'])
data_m['356: Forrest Gump (1994)']
# Out:
# mean    2.25
# Name: 356: Forrest Gump (1994), dtype: float64

# %% [markdown]
#  diff for  356: Forrest Gump (1994) is :  0.75

# %% [markdown]
# # 7 - (((((())))))

# %% [markdown]
# Next, compute the % of ratings 4+ separately for males and females. You'll be asked to submit two movies as above (largest difference in each direction). And again you'll indicate whether men or women are more likely to rate movies 4 stars or above.

# %%
# for females
data_females_ = data_females.copy()
data_males_ = data_males.copy()
for col in cols :
    data_females_[col] = data_females_[col].apply(lambda x: ofgreaterthan4(x))

# for males

for col in cols :
    data_males_[col] = data_males_[col].apply(lambda x: ofgreaterthan4(x))

# %%
data_males_
# Out:
#     User  Gender (1 =F, 0=M)  260: Star Wars: Episode IV - A New Hope (1977)  \
# 0      1                   0                                               0
# 1      1                   0                                               1
# 3      1                   0                                               0
# 6      1                   0                                               0
# 7      1                   0                                               1
# 9      1                   0                                               1
# 11     1                   0                                               0
# 12     1                   0                                               0
# 16     1                   0                                               0
# 18     1                   0                                               1
# 19     1                   0                                               0
#
# ...

# %%
# # And some oerall statistics:

# Average male rating: 2.906
# Percentage male ratings >=4: 0.3386

# %%
#for females 
Sum = data_females_.sum()
Count = data_females.count()
Liking_females = Sum/Count
print(Liking_females)
# Out:
# User                                                       1.000000
# Gender (1 =F, 0=M)                                         0.000000
# 260: Star Wars: Episode IV - A New Hope (1977)             0.571429
# 1210: Star Wars: Episode VI - Return of the Jedi (1983)    0.500000
# 356: Forrest Gump (1994)                                   0.500000
# 318: Shawshank Redemption, The (1994)                      0.800000
# 593: Silence of the Lambs, The (1991)                      0.285714
# 3578: Gladiator (2000)                                     0.500000
# 1: Toy Story (1995)                                        0.571429
# 2028: Saving Private Ryan (1998)                           0.500000
# 296: Pulp Fiction (1994)                                   0.666667
# 1259: Stand by Me (1986)                                   0.428571
# 2396: Shakespeare in Love (1998)                           0.750000
# 2916: Total Recall (1990)                                  0.000000
# ...

# %%
Sum = data_males_.sum()
Count = data_males.count()
Liking_males = Sum/Count
print(Liking_males)
Liking_males[2]
# Out:
# User                                                       1.000000
# Gender (1 =F, 0=M)                                         0.000000
# 260: Star Wars: Episode IV - A New Hope (1977)             0.500000
# 1210: Star Wars: Episode VI - Return of the Jedi (1983)    0.250000
# 356: Forrest Gump (1994)                                   0.000000
# 318: Shawshank Redemption, The (1994)                      0.600000
# 593: Silence of the Lambs, The (1991)                      0.555556
# 3578: Gladiator (2000)                                     0.500000
# 1: Toy Story (1995)                                        0.200000
# 2028: Saving Private Ryan (1998)                           0.285714
# 296: Pulp Fiction (1994)                                   0.250000
# 1259: Stand by Me (1986)                                   0.250000
# 2396: Shakespeare in Love (1998)                           0.000000
# 2916: Total Recall (1990)                                  0.200000
# ...

# %%
diff__= []
for col in cols:
    diff = Liking_females[col].item() - Liking_males[col].item()
    print("diff for ",col,"is : ", diff)
    diff__.append(diff)
diff__.sort()
print(diff__)
# Out:
# diff for  User is :  0.0
# diff for  Gender (1 =F, 0=M) is :  0.0
# diff for  260: Star Wars: Episode IV - A New Hope (1977) is :  0.0714285714285714
# diff for  1210: Star Wars: Episode VI - Return of the Jedi (1983) is :  0.25
# diff for  356: Forrest Gump (1994) is :  0.5
# diff for  318: Shawshank Redemption, The (1994) is :  0.20000000000000007
# diff for  593: Silence of the Lambs, The (1991) is :  -0.2698412698412699
# diff for  3578: Gladiator (2000) is :  0.0
# diff for  1: Toy Story (1995) is :  0.3714285714285714
# diff for  2028: Saving Private Ryan (1998) is :  0.2142857142857143
# diff for  296: Pulp Fiction (1994) is :  0.41666666666666663
# diff for  1259: Stand by Me (1986) is :  0.17857142857142855
# diff for  2396: Shakespeare in Love (1998) is :  0.75
# diff for  2916: Total Recall (1990) is :  -0.2
# diff for  780: Independence Day (ID4) (1996) is :  0.047619047619047616
# diff for  541: Blade Runner (1982) is :  0.55
# ...

# %% [markdown]
# # answer
#
# diff for  1198: Raiders of the Lost Ark (1981) is :  -0.5
#
# Females
#
# diff for  2396: Shakespeare in Love (1998) is :  0.75

# %% [markdown]
# =======================================
#
#
# And some overall statistics:
#
# Average male rating: 2.906
#
#
# Percentage male ratings >=4: 0.3386

# %%
data_females_.drop(['User','Gender (1 =F, 0=M)'],axis = 1,inplace = True)
data_females_
# Out:
#     260: Star Wars: Episode IV - A New Hope (1977)  \
# 2                                                0
# 4                                                1
# 5                                                0
# 8                                                1
# 10                                               0
# 13                                               0
# 14                                               1
# 15                                               0
# 17                                               1
#
#     1210: Star Wars: Episode VI - Return of the Jedi (1983)  \
# 2                                                   0
# 4                                                   0
# 5                                                   1
# 8                                                   0
# 10                                                  0
# 13                                                  0
# 14                                                  1
# ...

# %%
data_females.drop(['User','Gender (1 =F, 0=M)'],axis = 1 , inplace = True)
data_females
# Out:
#     260: Star Wars: Episode IV - A New Hope (1977)  \
# 2                                              NaN
# 4                                              4.0
# 5                                              2.0
# 8                                              5.0
# 10                                             2.0
# 13                                             3.0
# 14                                             4.0
# 15                                             NaN
# 17                                             4.0
#
#     1210: Star Wars: Episode VI - Return of the Jedi (1983)  \
# 2                                                 NaN
# 4                                                 3.0
# 5                                                 4.0
# 8                                                 1.0
# 10                                                1.0
# 13                                                NaN
# 14                                                4.0
# ...

# %%
data_males.drop(['User','Gender (1 =F, 0=M)'],axis = 1,inplace = True)
data_males
# Out:
#     260: Star Wars: Episode IV - A New Hope (1977)  \
# 0                                              1.0
# 1                                              5.0
# 3                                              NaN
# 6                                              NaN
# 7                                              4.0
# 9                                              4.0
# 11                                             3.0
# 12                                             2.0
# 16                                             NaN
# 18                                             5.0
# 19                                             1.0
#
#     1210: Star Wars: Episode VI - Return of the Jedi (1983)  \
# 0                                                 5.0
# 1                                                 3.0
# 3                                                 3.0
# 6                                                 NaN
# 7                                                 NaN
# ...

# %%
data_females_
# Out:
#     260: Star Wars: Episode IV - A New Hope (1977)  \
# 2                                                0
# 4                                                1
# 5                                                0
# 8                                                1
# 10                                               0
# 13                                               0
# 14                                               1
# 15                                               0
# 17                                               1
#
#     1210: Star Wars: Episode VI - Return of the Jedi (1983)  \
# 2                                                   0
# 4                                                   0
# 5                                                   1
# 8                                                   0
# 10                                                  0
# 13                                                  0
# 14                                                  1
# ...

# %%
data_males_
# Out:
#     User  Gender (1 =F, 0=M)  260: Star Wars: Episode IV - A New Hope (1977)  \
# 0      1                   0                                               0
# 1      1                   0                                               1
# 3      1                   0                                               0
# 6      1                   0                                               0
# 7      1                   0                                               1
# 9      1                   0                                               1
# 11     1                   0                                               0
# 12     1                   0                                               0
# 16     1                   0                                               0
# 18     1                   0                                               1
# 19     1                   0                                               0
#
# ...

# %%
cols = data_males.columns

# %%
import math

count_rating4 = 0
count_rating_ = 0


for col in cols : 
    for element in data_males[col]:
        if element >= 4 :
            count_rating4 = count_rating4 +1
        elif element < 4 :
            count_rating_ = count_rating_ +1
        elif math.isnan(element):
            continue
#males rating greter than 4 
result_males = count_rating4 / (count_rating4+count_rating_)

# %% [markdown]
# # check 7

# %%
result_males
# Out:
# 0.33858267716535434

# %%
import math

count_rating4 = 0
count_rating_ = 0


for col in cols : 
    for element in data_females[col]:
        if element >= 4 :
            count_rating4 = count_rating4 +1
        elif element < 4 :
            count_rating_ = count_rating_ +1
        elif math.isnan(element):
            continue
#males rating greter than 4 
result_females = count_rating4 / (count_rating4+count_rating_)

# %%
result = result_females - result_males

# %%
result
# Out:
# 0.082469954413593
